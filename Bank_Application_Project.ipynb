# %%
import json
data={
    '1001':['Prachi',123213,'kuchbhi@123','1204'],##ddmm
    '1002':['Aarti',123124,'bournvita@123','2305'],
    '1003':['Mansi',543534,'chai@123','1406'],
    '1004':['Lokesh',254356,'hello@123','1007'],
    '1005':['Sharad',5757657,'saras@123','2008']
}
with open("Bank_Data.txt","w") as fp:
    json.dump(data,fp)

# %%
import json
from getpass import getpass
class Python_Bank:
    def __init__(self,filename):
        with open(filename) as fp:
            self.data=json.load(fp)
        self.file=filename
        
    def authenticate(self,acc_no,passwd):
        if acc_no in self.data:
            if passwd==self.data[acc_no][2]:
                self.acc_no=acc_no
                return True
            return False
        else:
            return False
        
    def credit(self,acc_no):
        cre=int(input("Enter the amount ----> "))
        self.data[acc_no][1]=self.data[acc_no][1]+cre
        with open("Bank_Data.txt","w") as fp:
            json.dump(self.data,fp)
        print("TRANSACTION SUCCESSFULL COMEPLETED".center(80,"*"))
        print("\n1. Credit\n2. Debit\n3. Change Password\n4. Check Balance\n5. Logout")
        
        
    def debit(self,acc_no):
        deb=int(input("Enter the amount ----> "))
        self.data[acc_no][1]=self.data[acc_no][1]-deb
        with open("Bank_Data.txt","w") as fp:
            json.dump(self.data,fp)
        print("TRANSACTION SUCCESSFULL COMEPLETED".center(80,"*"))
        print("\n1. Credit\n2. Debit\n3. Change Password\n4. Check Balance\n5. Logout")
        
        
    def change_balance(self,acc_no):
        print(f"Amount is ---->{self.data[acc_no][1]}".center(80,"*"))
        print("\n1. Credit\n2. Debit\n3. Change Password\n4. Check Balance\n5. Logout")
        
    
    def change_password(self,acc_no):
        pas=getpass("Please Enter The Correct Password ---> ")
        if pas==self.data[acc_no][2]:
            pc=getpass("Please Enter The New Password ----> ")
            count=0
            upr=0
            lwr=0
            sc=0
            for s in pc:
                if s.innumeric():
                    count+=1
            for d in pc:
                if d.isupper():
                    upr+=1
            for e in pc:
                if e.islower():
                    lwr+=1
            special="!@#$%^&*()-_+=?/<,>"
            for x in pc:
                if x in special:
                    sc+=1
            if len(pc)>8:
                if count>=1:
                    if upr>=1:
                        if lwr>=1:
                            if sc>=1:
                                self.data[acc_no][2]=pc
                                with open("Bank_Data.txt","w") as fp:
                                    json.dump(self.data,fp)
                                print("YOUR PASSWORD HAS BEEN CHANGED".center(80,'*'))
                                print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Log Out\n")
                            else:
                                print("PLEASE ENTER STRONG PASSWORD!!!!!!!!!!".center(80,''))
                                print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Log Out\n")
                        else:
                            print("PLEASE ENTER STRONG PASSWORD!!!!!!!!!!".center(80,''))
                            print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Log Out\n")
                    else:
                        print("PLEASE ENTER STRONG PASSWORD!!!!!!!!!!".center(80,''))
                        print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Log Out\n")
                else:
                    print("PLEASE ENTER STRONG PASSWORD!!!!!!!!!!".center(80,''))
                    print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Log Out\n")
            else:
                print("PLEASE ENTER STRONG PASSWORD!!!!!!!!!!".center(80,''))
                print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Log Out\n")
        else:
            print("PLEASE ENTER VALID PASSWORD!!!!!!!!!!")
            PRINT("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Log Out\n")
            
    def signup(self,name,bal):
        while True:
            passw1=getpass("Enter the password ----> ")
            count=0
            upr=0
            lwr=0
            sp=0
            for s in passw1:
                if s.isnumeric():
                    count+=1
            for d in passw1:
                if  d.isupper():
                    upr+=1
            for x in passw1:
                if  x.islower():
                    lwr+=1  
            special = "!@#$%^&*()-+?_=,<>/"
            for o in passw1:
                if o in special:
                    sp+=1
            if len(passw1)>=8:
                if count>=1:
                    if upr>=1:
                        if lwr>=1:
                            if sp>=1:
                                dob=getpass("Enter your security in dob ---> ")
                                month=dob[2:5]
                                date=dob[0:2]
                                if dob.isnumeric():
                                    if int(month)%2==1 and int(month)!=2 and 1<=int(month)<=7:
                                        if 1<=int(date)<31:
                                            m=[*data]
                                            n=int(m[-1])
                                            self.data[str(n+1)]=[name,bal,passw1,dob]
                                            with open("Bant_Data.txt","w") as fp:
                                                json.dump(self.data,fp)
                                            print("ACCOUNT HAS BEEN OPENED".center(80,"*"))
                                            print()
                                            print("YOUR ACCOUNT NUMBER IS ----> ",str(n+1))
                                            print()
                                            print("THANK YOU".center(80,"*"))
                                            break
                                        else:
                                            print("PLEASE ENTER A VALID DATE!!!!!!!!".center(80))
                                    elif int(month)==2:
                                        if 1<=int(date)<=29:
                                            m=[*date]
                                            n=int(m[-1])
                                            self.data[str(n+1)]=[name,bal,passw1,dob]
                                            with open("Bank_data.txt","w") as fp:
                                                json.dump(self.data,fp)
                                            print("ACCOUNT HAS BEEN OPENED".center(80,"*"))
                                            print()
                                            print("YOUR ACCOUNT NUMBER IS ---->", str(n+1))
                                            print()
                                            print(" THANK YOU ".center(80,"*"))
                                            break
                                        else:
                                            print("ENTER VALID DATE!!!!!!!!!".center(80))
                                    elif int(month)%2==0 and int(month)!=0 and 8<=int(month)<=12:
                                        if 1<=int(date)<=31:
                                            m = [*data]
                                            n = int(m[-1])
                                            self.data[str(n+1)]=[name, bal, passw1,dob]
                                            with open("bank_data_2.txt","w") as fp:
                                                json.dump(self.data,fp)
                                            print("CONGRATULATIONS YOUR ACCOUNT HAS BEEN OPENED".center(80,"*"))
                                            print()
                                            print("YOUR ACCOUNT NUMBER IS ---->", str(n+1))
                                            print()
                                            print(" THANK YOU ".center(80,"*"))
                                            break
                                        else:
                                            print(" PLEASE ENTER A VALID DATE!!!!!!!!!!!!!!!!!!!".center(80))
                                    elif 1<=int(month)<=12:
                                        if 1<=int(date)<=30:
                                            m = [*data]
                                            n = int(m[-1])
                                            self.data[str(n+1)]=[name, bal, passw1,dob]
                                            with open("Bank_Data_2.txt","w") as fp:
                                                json.dump(self.data,fp)
                                            print("YOUR ACCOUNT HAS BEEN OPENED".center(80,"*"))
                                            print()
                                            print("YOUR ACCOUNT NUMBER IS ---->", str(n+1))
                                            print()
                                            print(" THANK YOU ".center(80,"*"))
                                            break
                                        else:
                                            print(" PLEASE ENTER A VALID DATE!!!!!!!!!!!!!!!!!!!".center(80))
                                    else:
                                        print(" ENTER THE VALID DATE!!!!!!!!!!!!!!!!".center(80))
                                else:
                                    print(" ENTER THE VALID DATE!!!!!!!!!!!!!!!!".center(80))
                            else:
                                print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!".center(80))
                        else:
                            print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!!".center(80))
                    else:
                        print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!".center(80))
                else:
                    print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!".center(80))                            
            else:
                print(" PLEASE ENTER THE MININUM 8 CHARACTER!!!!!!!!!!!!!!".center(80))
                
                
    def forget_pass(self,ac):
        new=getpass("Enter Your New Password".center(80,"*"))
        count=0
        upr=0
        lwr=0
        sp=0
        for p in new:
            if p.isnumeric():
                count+=1
        for q in new:
            if p.isupper():
                upr+=1
        for r in new:
            if r.islower():
                lwr+=1
        special="!@#$%^&*()-+_=?/<,.>\|"
        for s in new:
            if s in special:
                sp+=1
        if len(new)>=8:
            if count>=1:
                if upr>=1:
                    if lwr>=1:
                        if sp>=1:
                            self.data[ac_uy][2]=new
                            with open("Bank_Data.txt","w") as fp:
                                json.dump(self.data,fp)
                            print("YOUR PASSWORD IS UPDATED".center(80,"*"))
                            print()
                        else:
                            print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!!!".center(80))
                    else:
                            print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!!!".center(80))
                else:
                            print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!!!".center(80))
            else:
                            print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!!!".center(80))
        else:
                            print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!!!".center(80))
        
def main():
        user=Python_Bank("Bank_Data.txt")
        while True:
            print("\n$--Main Menu--$")
            print("\n1. Login\n2. SignUp\n3. Forgot Password\n4. Exit")
            choice=input("PLEASE CHOOSE FROM CHOICE FROM THESE FOUR ITEMS ----> ")
            if choice=="1":
                acc_no = input("\nEnter your Account Number --> ")
                password=getpass("\n Enter the password----->")
                res=user.authenticate(acc_no,password)
                if res:
                    print()
                    print(f"Hello{data[acc_no][0]} ! Welcome to Python Bank".center(85,"-"))
                    print()
                    print("\n1. Credit\n2. Debit\n3. Change Password\n4. Check Balance\n5. Logout")
                    while True:
                        qw=input("Enter a choice ----> ")
                        if qw=='1':
                            user.credit(acc_no)

                        elif qw=="2":
                            user.debit(acc_no)

                        elif qw=="3":
                            user.change_password(acc_no)

                        elif qw=="4":
                            user.check_password(acc_no)

                        elif qw=="5":
                            break

                        else:
                            print("\nENTER CORRECT PASSWORD OR ACCOUNT NUMBER")


            elif choice=="2":
                print("\n$--Welcome to Signup Menu--$")
                name=input("Enter the name ----> ")
                bal=int(input("Enter your balance ---> "))
                if bal>=1000:
                    user.signup(name,bal)
                else:
                    print("PLEASE ENTER VALID BALANCE AND GREATER THAN 1000".center(85))


            elif choice=="3":
                print("\n$--Welcome to Forgot Password--$\n")
                ac=input("ENTER YOUR ACCOUNT NUMBER ----> ")
                if ac in data:
                    dob=data[ac][3]
                    sc=getpass("ENTER YOUR SECURITY CODE")
                    if dob==sc:
                        user.forget_pass(ac)
                    else:
                        print("PLEASE ENTER CORRECT SECURITY CODE".center(80))
                else:
                    print("INCORRECT ACCOUNT NUMBER".center(80))


            elif choice=="4":
                print(" Thank You ".center(80,"*"))
                break

            else:
                print("PLEASE CHOOSE FROM THESE FOUR".center(80))

main()
# Out:
# $--Main Menu--$
#
# 1. Login
# 2. SignUp
# 3. Forgot Password
# 4. Exit
# PLEASE CHOOSE FROM CHOICE FROM THESE FOUR ITEMS ----> 1001
#                          PLEASE CHOOSE FROM THESE FOUR
#
# $--Main Menu--$
#
# 1. Login
# 2. SignUp
# 3. Forgot Password
# 4. Exit
# PLEASE CHOOSE FROM CHOICE FROM THESE FOUR ITEMS ----> 1001
#                          PLEASE CHOOSE FROM THESE FOUR
#
# $--Main Menu--$
#
# 1. Login
# 2. SignUp
# 3. Forgot Password
# 4. Exit
# PLEASE CHOOSE FROM CHOICE FROM THESE FOUR ITEMS ----> kucbhi@123
#                          PLEASE CHOOSE FROM THESE FOUR
#
# $--Main Menu--$
#
# 1. Login
# 2. SignUp
# 3. Forgot Password
# 4. Exit
# PLEASE CHOOSE FROM CHOICE FROM THESE FOUR ITEMS ----> 1
#
# Enter your Account Number --> 1001
#
#  Enter the password----->········
#
# -------------------------Hellosimran ! Welcome to Python Bank------------------------
#
#
# 1. Credit
# 2. Debit
# 3. Change Password
# 4. Check Balance
# 5. Logout
# Enter a choice ----> 1
# ...
